# %%
import marvel
from IPython.display import Image, HTML, display
PUBLIC_KEY = '你的公钥'
PRIVATE_KEY = '你的私钥'
m = marvel.Marvel(PUBLIC_KEY, PRIVATE_KEY)
characters = m.characters
name = input('请输入要查询的英雄（英文，可只输入开头）：')
print('搜索中...')
all_characters = characters.all(nameStartsWith=name)
# Out:
# 请输入要查询的英雄（英文，可只输入开头）：captain america
# 搜索中...

# %% [markdown]
# 输入下面这些试试
# - captain america
# - super

# %%
print(all_characters)
# Out:
# {'etag': '32fba244ee4b33dbeb095fed1d32988c22afd485', 'data': {'offset': 0, 'count': 7, 'results': [{'id': 1009220, 'name': 'Captain America', 'modified': '2016-09-06T11:37:19-0400', 'description': "Vowing to serve his country any way he could, young Steve Rogers took the super soldier serum to become America's one-man army. Fighting for the red, white and blue for over 60 years, Captain America is the living, breathing symbol of freedom and liberty.", 'events': {'returned': 20, 'available': 29, 'items': [{'name': 'Acts of Vengeance!', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/116'}, {'name': 'Age of Ultron', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/314'}, {'name': 'Age of X', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/303'}, {'name': 'Armor Wars', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/231'}, {'name': 'Avengers Disassembled', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/234'}, {'name': 'Avengers VS X-Men', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/310'}, {'name': 'Axis', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/320'}, {'name': 'Chaos War', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/296'}, {'name': 'Civil War', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/238'}, {'name': 'Fall of the Mutants', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/248'}, {'name': 'Fear Itself', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/302'}, {'name': 'House of M', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/251'}, {'name': 'Inferno', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/252'}, {'name': 'Infinity', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/315'}, {'name': 'Infinity War', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/29'}, {'name': 'Inhumanity', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/317'}, {'name': 'Maximum Carnage', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/151'}, {'name': 'Maximum Security', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/37'}, {'name': 'Monsters Unleashed', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/337'}, {'name': 'Monsters Unleashed', 'resourceURI': 'http://gateway.marvel.com/v1/public/events/333'}], 'collectionURI': 'http://gateway.marvel.com/v1/public/characters/1009220/events'}, 'thumbnail': {'path': 'http://i.annihil.us/u/prod/marvel/i/mg/3/50/537ba56d31087', 'extension': 'jpg'}, 'resourceURI': 'http://gateway.marvel.com/v1/public/characters/1009220', 'comics': {'returned': 20, 'available': 2224, 'items': [{'name': 'A+X (2012) #1', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/43488'}, {'name': 'A+X (2012) #4', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/43501'}, {'name': 'A+X (2012) #9', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/43508'}, {'name': 'A-Next (1998) #11', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/17741'}, {'name': 'Adventures of Captain America (1991) #1', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/66978'}, {'name': 'Adventures of Captain America (1991) #2', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/66979'}, {'name': 'Adventures of Captain America (1991) #3', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/66980'}, {'name': 'Adventures of Captain America (1991) #4', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/66981'}, {'name': 'Age of Apocalypse (2011) #2 (Avengers Art Appreciation Variant)', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/42539'}, {'name': 'Age of Heroes (Trade Paperback)', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30885'}, {'name': 'Age of Heroes (2010) #1', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30090'}, {'name': 'Age of Heroes (2010) #4', 'resourceURI': 'http://gateway.marvel.com/v1/public/comics/30093'}, {'name': 'Age of X ...
